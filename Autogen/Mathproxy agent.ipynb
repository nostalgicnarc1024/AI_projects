# %%
import os
from dotenv import load_dotenv
from autogen import ConversableAgent

load_dotenv()
api_key = os.getenv("MY_KEY")

llm_config={"config_list": [{"model": "gpt-4o-mini", "api_key": api_key}]}

# %%
import autogen
from autogen.agentchat.contrib.math_user_proxy_agent import MathUserProxyAgent

assistant = autogen.AssistantAgent(
    name="assistant",
    system_message="You are a helpful assistant.",
    llm_config=llm_config
)

# %%
math_proxy_agent = MathUserProxyAgent(
    name="math_proxy_agent",
    human_input_mode="NEVER",
    code_execution_config={"use_docker": False},
)

# %%
#math_problem: "Problem: If 72x + 27y = 1500 and 29x+ 31y = 1508, what is the value of x - y ?"
math_proxy_agent.initiate_chat(assistant)
# Out:
# math_proxy_agent (to assistant):
#
# If 72x + 27y = 1500 and 29x+ 31y = 1508, what is the value of x - y ?
#
# --------------------------------------------------------------------------------
# assistant (to math_proxy_agent):
#
# We are given the equations:
#
# 1. \( 72x + 27y = 1500 \) (Equation 1)
# 2. \( 29x + 31y = 1508 \) (Equation 2)
#
# We want to find the value of \( x - y \).
#
# Let's solve the system of equations step-by-step.
#
# First, we can solve Equation 1 for one of the variables. Let's solve for \( y \):
#
# \[
# 27y = 1500 - 72x
# \]
#
# Dividing both sides by 27 gives us:
#
# \[
# y = \frac{1500 - 72x}{27} \quad (1)
# \]
#
# Next, substitute \( y \) from Equation (1) into Equation 2:
#
# \[
# 29x + 31\left(\frac{1500 - 72x}{27}\right) = 1508
# \]
#
# Multiply through by 27 to eliminate the fraction:
#
# \[
# 27 \cdot 29x + 31(1500 - 72x) = 27 \cdot 1508
# \]
#
# Calculating the left-hand side:
#
# \[
# 783x + 46500 - 2232x = 40656
# \]
#
# Combine like terms:
#
# \[
# -1449x + 46500 = 40656
# \]
#
# Subtract 46500 from both sides:
#
# \[
# -1449x = 40656 - 46500
# \]
#
# Calculating the right-hand side:
#
# \[
# -1449x = -5844
# \]
#
# Dividing both sides by -1449 gives:
#
# \[
# x = \frac{5844}{1449}
# \]
#
# Calculating this fraction gives:
#
# \[
# x = 4
# \]
#
# Now substitute \( x = 4 \) back into Equation (1) to find \( y \):
#
# \[
# 72(4) + 27y = 1500
# \]
# \[
# 288 + 27y = 1500
# \]
#
# Subtract \( 288 \) from both sides:
#
# \[
# 27y = 1212
# \]
#
# Dividing both sides by 27 gives:
#
# \[
# y = \frac{1212}{27}
# \]
#
# Calculating this yields:
#
# \[
# y = 45
# \]
#
# We found: \( x = 4 \) and \( y = 45 \).
#
# Now, we need to find \( x - y \):
#
# \[
# x - y = 4 - 45 = -41
# \]
#
# Thus, the value of \( x - y \) is:
#
# \[
# \boxed{-41}
# \]
#
# --------------------------------------------------------------------------------
# ChatResult(chat_id=None, chat_history=[{'content': 'If 72x + 27y = 1500 and 29x+ 31y = 1508, what is the value of x - y ?', 'role': 'assistant'}, {'content': "We are given the equations:\n\n1. \\( 72x + 27y = 1500 \\) (Equation 1)\n2. \\( 29x + 31y = 1508 \\) (Equation 2)\n\nWe want to find the value of \\( x - y \\).\n\nLet's solve the system of equations step-by-step.\n\nFirst, we can solve Equation 1 for one of the variables. Let's solve for \\( y \\):\n\n\\[\n27y = 1500 - 72x\n\\]\n\nDividing both sides by 27 gives us:\n\n\\[\ny = \\frac{1500 - 72x}{27} \\quad (1)\n\\]\n\nNext, substitute \\( y \\) from Equation (1) into Equation 2:\n\n\\[\n29x + 31\\left(\\frac{1500 - 72x}{27}\\right) = 1508\n\\]\n\nMultiply through by 27 to eliminate the fraction:\n\n\\[\n27 \\cdot 29x + 31(1500 - 72x) = 27 \\cdot 1508\n\\]\n\nCalculating the left-hand side:\n\n\\[\n783x + 46500 - 2232x = 40656\n\\]\n\nCombine like terms:\n\n\\[\n-1449x + 46500 = 40656\n\\]\n\nSubtract 46500 from both sides:\n\n\\[\n-1449x = 40656 - 46500\n\\]\n\nCalculating the right-hand side:\n\n\\[\n-1449x = -5844\n\\]\n\nDividing both sides by -1449 gives:\n\n\\[\nx = \\frac{5844}{1449}\n\\]\n\nCalculating this fraction gives:\n\n\\[\nx = 4\n\\]\n\nNow substitute \\( x = 4 \\) back into Equation (1) to find \\( y \\):\n\n\\[\n72(4) + 27y = 1500\n\\]\n\\[\n288 + 27y = 1500\n\\]\n\nSubtract \\( 288 \\) from both sides:\n\n\\[\n27y = 1212\n\\]\n\nDividing both sides by 27 gives:\n\n\\[\ny = \\frac{1212}{27}\n\\]\n\nCalculating this yields:\n\n\\[\ny = 45\n\\]\n\nWe found: \\( x = 4 \\) and \\( y = 45 \\).\n\nNow, we need to find \\( x - y \\):\n\n\\[\nx - y = 4 - 45 = -41\n\\]\n\nThus, the value of \\( x - y \\) is:\n\n\\[\n\\boxed{-41}\n\\]", 'role': 'user'}], summary="We are given the equations:\n\n1. \\( 72x + 27y = 1500 \\) (Equation 1)\n2. \\( 29x + 31y = 1508 \\) (Equation 2)\n\nWe want to find the value of \\( x - y \\).\n\nLet's solve the system of equations step-by-step.\n\nFirst, we can solve Equation 1 for one of the variables. Let's solve for \\( y \\):\n\n\\[\n27y = 1500 - 72x\n\\]\n\nDividing both sides by 27 gives us:\n\n\\[\ny = \\frac{1500 - 72x}{27} \\quad (1)\n\\]\n\nNext, substitute \\( y \\) from Equation (1) into Equation 2:\n\n\\[\n29x + 31\\left(\\frac{1500 - 72x}{27}\\right) = 1508\n\\]\n\nMultiply through by 27 to eliminate the fraction:\n\n\\[\n27 \\cdot 29x + 31(1500 - 72x) = 27 \\cdot 1508\n\\]\n\nCalculating the left-hand side:\n\n\\[\n783x + 46500 - 2232x = 40656\n\\]\n\nCombine like terms:\n\n\\[\n-1449x + 46500 = 40656\n\\]\n\nSubtract 46500 from both sides:\n\n\\[\n-1449x = 40656 - 46500\n\\]\n\nCalculating the right-hand side:\n\n\\[\n-1449x = -5844\n\\]\n\nDividing both sides by -1449 gives:\n\n\\[\nx = \\frac{5844}{1449}\n\\]\n\nCalculating this fraction gives:\n\n\\[\nx = 4\n\\]\n\nNow substitute \\( x = 4 \\) back into Equation (1) to find \\( y \\):\n\n\\[\n72(4) + 27y = 1500\n\\]\n\\[\n288 + 27y = 1500\n\\]\n\nSubtract \\( 288 \\) from both sides:\n\n\\[\n27y = 1212\n\\]\n\nDividing both sides by 27 gives:\n\n\\[\ny = \\frac{1212}{27}\n\\]\n\nCalculating this yields:\n\n\\[\ny = 45\n\\]\n\nWe found: \\( x = 4 \\) and \\( y = 45 \\).\n\nNow, we need to find \\( x - y \\):\n\n\\[\nx - y = 4 - 45 = -41\n\\]\n\nThus, the value of \\( x - y \\) is:\n\n\\[\n\\boxed{-41}\n\\]", cost={'usage_including_cached_inference': {'total_cost': 0, 'gpt-4o-mini-2024-07-18': {'cost': 0, 'prompt_tokens': 107, 'completion_tokens': 1614, 'total_tokens': 1721}}, 'usage_excluding_cached_inference': {'total_cost': 0, 'gpt-4o-mini-2024-07-18': {'cost': 0, 'prompt_tokens': 107, 'completion_tokens': 1614, 'total_tokens': 1721}}}, human_input=['If 72x + 27y = 1500 and 29x+ 31y = 1508, what is the value of x - y ?'])
